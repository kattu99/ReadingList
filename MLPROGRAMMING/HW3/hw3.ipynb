# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from scipy import ndimage

# %%
y = np.empty(499)
y.fill(0.01)
interval = 20/499.0
print(interval)
x_values = []
start = -10
for i in range(500):
    x_values.append(start)
    start += interval
squared = [np.sin(x) for x in x_values]
print(len(squared))
print(x_values)
x = np.random.multivariate_normal(squared, np.identity(500))
print(np.ones((500,500)) + np.ones((500,500)) + np.diag(y, -1) + np.diag(y, 1))
# Out:
# 0.04008016032064128
# 500
# ...

# %%
print(x)
# Out:
# [ 5.58214273e-01  5.43860166e-01 -5.48231991e-01 -6.40122924e-02
#   6.90831828e-01  7.02135200e-01  7.70594385e-01 -1.67847732e+00
#  -2.92307411e-01  1.60479041e+00  2.18270241e-01 -5.63746652e-02
#  -3.86751068e-01 -1.47189354e-01 -1.92011877e+00  1.42636994e+00
#   8.46376222e-01 -1.85054549e-01  1.60449671e+00  1.01177597e+00
#   3.40534561e-01 -1.83711999e+00  7.94150942e-01 -9.30019193e-01
#  -1.33504676e+00 -5.34224544e-01 -1.13590139e-01 -1.32959716e+00
#  -9.18010045e-01  3.19920470e-01  9.51772754e-01  2.11807550e-01
#   5.82236886e-01 -6.66685989e-01  1.16455951e-01  1.39668374e+00
#  -9.21119284e-01 -1.92811567e+00 -1.10750931e+00 -1.23785939e+00
#   1.30243126e+00 -2.60343775e+00 -1.39067016e+00  1.55173030e+00
#   7.78189916e-02 -2.13445077e+00 -2.14497607e+00 -4.04326576e-01
#  -2.08280999e-01 -1.42385309e+00 -6.95073609e-01 -9.30658580e-01
#  -1.83496651e+00 -1.65080959e+00 -1.60592369e+00 -1.40051106e+00
# ...

# %%
plt.plot(x)
plt.ylim(-3, 3)
plt.show()

# %%
import random

lst = ['Shiv', 'Haris', 'Rob']
index = int(random.random*3)
print(lst[index])
